# %% [markdown]
# ## BREAK AND CONTINUE STATEMENTS

# %% [markdown]
# ### LEVEL 1 – BASIC (Break)

# %% [markdown]
# #### 1. Print numbers from 1 to 10, but stop at 5.

# %% [markdown]
# #### 2. Print numbers until user enters 0.

# %% [markdown]
# #### 3. Print elements of a list, stop if element is negative.

# %% [markdown]
# #### 4. Search a number in a list, stop when found.

# %% [markdown]
# #### 5. Print characters of a string, stop at first vowel.

# %% [markdown]
# #### 6. Print multiplication table but stop when result > 50.

# %% [markdown]
# #### 7. Loop through range 1–100, stop at first multiple of 7.

# %% [markdown]
# #### 8. Print numbers until number divisible by 3 appears.

# %% [markdown]
# #### 9. Stop loop when password matches.

# %% [markdown]
# #### 10. Stop loop when sum exceeds 100.

# %% [markdown]
# ### LEVEL 2 – INTERMEDIATE (Break)

# %% [markdown]
# #### 11. Find first prime number in range 1–100.

# %% [markdown]
# #### 12. Find first even number in list.

# %% [markdown]
# #### 13. Stop nested loop when condition is met.

# %% [markdown]
# #### 14. Find first duplicate element in list.

# %% [markdown]
# #### 15. Search character in string.

# %% [markdown]
# #### 16. Find first palindrome in list.

# %% [markdown]
# #### 17. Stop when cumulative total crosses 500.

# %% [markdown]
# #### 18. Break loop when invalid input entered.

# %% [markdown]
# #### 19. Find first number divisible by both 3 and 5.

# %% [markdown]
# #### 20. Stop reading file lines when keyword found.

# %% [markdown]
# ### PART 2: CONTINUE STATEMENT

# %% [markdown]
# ### LEVEL 1 – BASIC (Continue)

# %% [markdown]
# #### 21. Print numbers 1–10 but skip 5.

# %% [markdown]
# #### 22. Print only even numbers from 1–20.

# %% [markdown]
# #### 23. Print only odd numbers.

# %% [markdown]
# #### 24. Skip negative numbers in list.

# %% [markdown]
# #### 25. Skip vowels in a string.

# %% [markdown]
# #### 26. Print numbers except multiples of 3.

# %% [markdown]
# #### 27. Skip spaces in sentence.

# %% [markdown]
# #### 28. Print numbers except 0.

# %% [markdown]
# #### 29. Skip numbers divisible by 7.

# %% [markdown]
# #### 30. Print only positive numbers.

# %% [markdown]
# ### LEVEL 2 – INTERMEDIATE (Continue)

# %% [markdown]
# #### 31. Print non-duplicate elements.

# %% [markdown]
# #### 32. Skip invalid inputs.

# %% [markdown]
# #### 33. Skip numbers greater than 50.

# %% [markdown]
# #### 34. Print students who passed (skip failed).

# %% [markdown]
# #### 35. Skip empty strings in list.

# %% [markdown]
# #### 36. Skip numbers ending with 5.

# %% [markdown]
# #### 37. Skip leap years in range.

# %% [markdown]
# #### 38. Skip special characters in string.

# %% [markdown]
# #### 39. Print words longer than 3 letters.

# %% [markdown]
# #### 40. Skip numbers divisible by both 2 and 3.

# %% [markdown]
# ### LEVEL 3 – BREAK + CONTINUE MIXED

# %% [markdown]
# #### 41. Print numbers 1–20, skip even numbers, stop if number > 15.

# %% [markdown]
# #### 42. Find first negative number, skip zeros.

# %% [markdown]
# #### 43. Skip multiples of 5, break at 50.

# %% [markdown]
# #### 44. Password attempts (3 attempts, break if correct).

# %% [markdown]
# #### 45. Skip blank input, break on "exit".

# %% [markdown]
# #### 46. Game loop that breaks on win.

# %% [markdown]
# #### 47. Skip invalid scores, break on full score.

# %% [markdown]
# #### 48. Process list until error found.

# %% [markdown]
# #### 49. Skip failed transactions, stop if fraud detected.

# %% [markdown]
# #### 50. Student grading loop (skip absent, break if topper found).
