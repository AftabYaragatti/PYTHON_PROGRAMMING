# %% [markdown]
# ## For(Range,Enumerate) Looping Statements

# %% [markdown]
# ### BASIC LEVEL

# %% [markdown]
# ### Using `range()`

# %% [markdown]
# #### 1. Print numbers from 1 to 10.

# %% [markdown]
# #### 2. Print even numbers from 1 to 20.

# %% [markdown]
# #### 3. Print odd numbers from 1 to 15.

# %% [markdown]
# #### 4. Print numbers from 10 to 1 (reverse order).

# %% [markdown]
# #### 5. Print multiplication table of 5.

# %% [markdown]
# #### 6. Print squares of numbers from 1 to 10.

# %% [markdown]
# #### 7. Print cubes of numbers from 1 to 5.

# %% [markdown]
# #### 8. Print numbers divisible by 3 from 1 to 30.

# %% [markdown]
# #### 9. Print sum of numbers from 1 to 100.

# %% [markdown]
# #### 10. Print factorial of a number using `range()`.

# %% [markdown]
# #### Using `enumerate()`

# %% [markdown]
# #### 11. Print index and value of list: `[10, 20, 30, 40]`

# %% [markdown]
# #### 12. Print index starting from 1 for list `["a","b","c"]`

# %% [markdown]
# #### 13. Count how many elements are in a list using `enumerate()`

# %% [markdown]
# #### 14. Print only even index values from a list

# %% [markdown]
# #### 15. Print elements whose index is odd

# %% [markdown]
# ### INTERMEDIATE LEVEL

# %% [markdown]
# ### Using `range()`

# %% [markdown]
# #### 16. Print all prime numbers between 1 and 50.

# %% [markdown]
# #### 17. Print Fibonacci series up to 10 terms.

# %% [markdown]
# #### 18. Reverse a number using loop.

# %% [markdown]
# #### 19. Find sum of digits of a number.

# %% [markdown]
# #### 20. Print pattern:
# #### ```
# #### *
# #### **
# #### ***
# #### ****
# #### ```

# %% [markdown]
# #### 21. Print numbers divisible by both 3 and 5 from 1 to 100.

# %% [markdown]
# #### 22. Count how many numbers between 1–100 are divisible by 7.

# %% [markdown]
# #### 23. Print Armstrong numbers between 1 and 500.

# %% [markdown]
# #### 24. Find LCM of two numbers using loop.

# %% [markdown]
# #### 25. Find GCD using loop.

# %% [markdown]
# ### Using `enumerate()`

# %% [markdown]
# #### 26. Find index of a specific element in a list.

# %% [markdown]
# #### 27. Replace all negative numbers in list with 0 using index.

# %% [markdown]
# #### 28. Print duplicate elements along with their index.

# %% [markdown]
# #### 29. Count occurrences of each element using index.

# %% [markdown]
# #### 30. Reverse a list using index.

# %% [markdown]
# ### ADVANCED LEVEL

# %% [markdown]
# ### Using `range()`

# %% [markdown]
# #### 31. Create a pyramid number pattern.

# %% [markdown]
# #### 32. Print Pascal’s triangle using loops.

# %% [markdown]
# #### 33. Print diamond star pattern.

# %% [markdown]
# #### 34. Find all perfect numbers between 1–1000.

# %% [markdown]
# #### 35. Print prime factors of a number.

# %% [markdown]
# #### 36. Implement simple calculator using loop.

# %% [markdown]
# #### 37. Print multiplication table from 1 to 10.

# %% [markdown]
# #### 38. Generate matrix using nested `range()`.

# %% [markdown]
# #### 39. Transpose a matrix using loops.

# %% [markdown]
# #### 40. Print chessboard pattern using loops.

# %% [markdown]
# ### Using `enumerate()`

# %% [markdown]
# #### 41. Remove duplicates while keeping order.

# %% [markdown]
# #### 42. Find second largest element using index.

# %% [markdown]
# #### 43. Rotate list left by k positions.

# %% [markdown]
# #### 44. Implement manual `index()` function.

# %% [markdown]
# #### 45. Implement manual `count()` function.

# %% [markdown]
# #### 46. Swap elements at even and odd index.

# %% [markdown]
# #### 47. Separate elements based on index parity.

# %% [markdown]
# #### 48. Insert index position into each element.

# %% [markdown]
# #### 49. Modify list in-place using index.

# %% [markdown]
# #### 50. Compare two lists element-wise with index.
