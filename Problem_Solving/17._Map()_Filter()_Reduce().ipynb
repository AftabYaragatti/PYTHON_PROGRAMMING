# %% [markdown]
# ## MAP(), REDUCE(), FILTER() FUNCTIONS

# %% [markdown]
# ### BASIC LEVEL

# %% [markdown]
# ### Using `map()`

# %% [markdown]
# #### 1. Double all numbers in a list.

# %% [markdown]
# #### 2. Convert list of integers to strings.

# %% [markdown]
# #### 3. Convert list of strings to uppercase.

# %% [markdown]
# #### 4. Find square of each number.

# %% [markdown]
# #### 5. Add 5 to each element in list.

# %% [markdown]
# ### Using `filter()`

# %% [markdown]
# #### 6. Get even numbers from list.

# %% [markdown]
# #### 7. Get odd numbers from list.

# %% [markdown]
# #### 8. Get numbers greater than 10.

# %% [markdown]
# #### 9. Filter negative numbers.

# %% [markdown]
# #### 10. Get names longer than 4 characters.

# %% [markdown]
# ### Using `reduce()`

# %% [markdown]
# #### 11. Find sum of all numbers.

# %% [markdown]
# #### 12. Find product of all numbers.

# %% [markdown]
# #### 13. Find maximum value.

# %% [markdown]
# #### 14. Find minimum value.

# %% [markdown]
# #### 15. Count total characters in list of words.

# %% [markdown]
# ### INTERMEDIATE LEVEL

# %% [markdown]
# #### 16. Square only even numbers.

# %% [markdown]
# #### 17. Remove empty strings from list.

# %% [markdown]
# #### 18. Find sum of squares.

# %% [markdown]
# #### 19. Find factorial of a number using reduce.

# %% [markdown]
# #### 20. Get numbers divisible by both 3 and 5.

# %% [markdown]
# #### 21. Convert list of Celsius to Fahrenheit.

# %% [markdown]
# #### 22. Find longest word using reduce.

# %% [markdown]
# #### 23. Get all prime numbers from list.

# %% [markdown]
# #### 24. Merge two lists element-wise using map.

# %% [markdown]
# #### 25. Count how many numbers are even using reduce.

# %% [markdown]
# ### ADVANCED LEVEL

# %% [markdown]
# #### 26. Flatten a list of lists using reduce.

# %% [markdown]
# #### 27. Combine multiple dictionaries into one using reduce.

# %% [markdown]
# #### 28. Find second largest number using reduce.

# %% [markdown]
# #### 29. Find frequency of elements using reduce.

# %% [markdown]
# #### 30. Filter palindrome strings.

# %% [markdown]
# #### 31. Use map + filter together (e.g., square only odd numbers).

# %% [markdown]
# #### 32. Find GCD of list using reduce.

# %% [markdown]
# #### 33. Remove duplicates while keeping order.

# %% [markdown]
# #### 34. Transform matrix values using map.
