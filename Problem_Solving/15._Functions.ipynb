# %% [markdown]
# ## FUNCTIONS

# %% [markdown]
# ### BASIC LEVEL (Function Fundamentals)

# %% [markdown]
# #### 1. Write a function to print "Hello World".

# %% [markdown]
# #### 2. Write a function to add two numbers.

# %% [markdown]
# #### 3. Write a function to find square of a number.

# %% [markdown]
# #### 4. Write a function to check even or odd.

# %% [markdown]
# #### 5. Write a function to find maximum of two numbers.

# %% [markdown]
# #### 6. Write a function to return factorial of a number.

# %% [markdown]
# #### 7. Write a function to count vowels in a string.

# %% [markdown]
# #### 8. Write a function to reverse a string.

# %% [markdown]
# #### 9. Write a function to check palindrome string.

# %% [markdown]
# #### 10. Write a function to find sum of digits of a number.

# %% [markdown]
# #### 11. Write a function that returns multiplication table of a number.

# %% [markdown]
# #### 12. Write a function to find length of string without using `len()`.

# %% [markdown]
# #### 13. Write a function to check prime number.

# %% [markdown]
# #### 14. Write a function to return cube of a number.

# %% [markdown]
# #### 15. Write a function to calculate simple interest.

# %% [markdown]
# ### INTERMEDIATE LEVEL (Arguments & Return Types)

# %% [markdown]
# #### 16. Function using default arguments.

# %% [markdown]
# #### 17. Function using keyword arguments.

# %% [markdown]
# #### 18. Function using variable-length arguments (`*args`).

# %% [markdown]
# #### 19. Function using `**kwargs`.

# %% [markdown]
# #### 20. Function to return multiple values.

# %% [markdown]
# #### 21. Function to swap two numbers without using third variable.

# %% [markdown]
# #### 22. Recursive function for factorial.

# %% [markdown]
# #### 23. Recursive function for Fibonacci.

# %% [markdown]
# #### 24. Function to find GCD.

# %% [markdown]
# #### 25. Function to find LCM.

# %% [markdown]
# #### 26. Function to count frequency of characters in string.

# %% [markdown]
# #### 27. Function to remove duplicates from list.

# %% [markdown]
# #### 28. Function to sort list without using `sort()`.

# %% [markdown]
# #### 29. Function to find second largest number.

# %% [markdown]
# #### 30. Function to check Armstrong number.

# %% [markdown]
# ### ADVANCED LEVEL (Concept-Based)

# %% [markdown]
# #### 31. Write a lambda function for square.

# %% [markdown]
# #### 32. Use lambda with `map()` to double list values.

# %% [markdown]
# #### 33. Use lambda with `filter()` to get even numbers.

# %% [markdown]
# #### 34. Use lambda with `reduce()` to find product of list.

# %% [markdown]
# #### 35. Write a decorator function.

# %% [markdown]
# #### 36. Write a function inside another function (closure).

# %% [markdown]
# #### 37. Create a function factory (returns function).

# %% [markdown]
# #### 38. Write memoized recursive function.

# %% [markdown]
# #### 39. Create custom `map()` function.

# %% [markdown]
# #### 40. Create custom `filter()` function.

# %% [markdown]
# #### 41. Implement caching manually in function.

# %% [markdown]
# #### 42. Write generator function using `yield`.

# %% [markdown]
# #### 43. Write infinite generator.

# %% [markdown]
# #### 44. Function to validate email.

# %% [markdown]
# #### 45. Implement simple logging decorator.

# %% [markdown]
# #### 46. Create retry decorator.

# %% [markdown]
# #### 47. Measure execution time using decorator.

# %% [markdown]
# #### 48. Implement custom `enumerate()` function.

# %% [markdown]
# #### 49. Function to flatten nested list.

# %% [markdown]
# #### 50. Write tail recursion example.
