# %% [markdown]
# ## LAMBDA FUNCTIONS

# %% [markdown]
# ### LEVEL 1 – BASIC LAMBDA

# %% [markdown]
# #### 1. Write a lambda to square a number.

# %% [markdown]
# #### 2. Write a lambda to add two numbers.

# %% [markdown]
# #### 3. Write a lambda to check even or odd.

# %% [markdown]
# #### 4. Write a lambda to return maximum of two numbers.

# %% [markdown]
# #### 5. Write a lambda to return length of a string.

# %% [markdown]
# #### 6. Write a lambda to convert string to uppercase.

# %% [markdown]
# #### 7. Write a lambda to check if number is positive.

# %% [markdown]
# #### 8. Write a lambda to return last character of string.

# %% [markdown]
# #### 9. Write a lambda to multiply three numbers.

# %% [markdown]
# #### 10. Write a lambda to reverse a string.

# %% [markdown]
# ### LEVEL 2 – LAMBDA WITH `map()`

# %% [markdown]
# #### 11. Double all numbers in list.

# %% [markdown]
# #### 12. Convert list of strings to uppercase.

# %% [markdown]
# #### 13. Get square of each number.

# %% [markdown]
# #### 14. Convert Celsius list to Fahrenheit.

# %% [markdown]
# #### 15. Add 10 to each number.

# %% [markdown]
# #### 16. Get length of each word in list.

# %% [markdown]
# #### 17. Multiply two lists element-wise.

# %% [markdown]
# #### 18. Extract first character from each string.

# %% [markdown]
# #### 19. Convert list of strings to integers.

# %% [markdown]
# #### 20. Add index value to each element (use enumerate).

# %% [markdown]
# #### LEVEL 3 – LAMBDA WITH `filter()`

# %% [markdown]
# #### 21. Filter even numbers.

# %% [markdown]
# #### 22. Filter odd numbers.

# %% [markdown]
# #### 23. Filter numbers greater than 50.

# %% [markdown]
# #### 24. Remove negative numbers.

# %% [markdown]
# #### 25. Filter palindrome strings.

# %% [markdown]
# #### 26. Filter names starting with 'A'.

# %% [markdown]
# #### 27. Filter prime numbers.

# %% [markdown]
# #### 28. Remove empty strings.

# %% [markdown]
# #### 29. Filter words longer than 5 letters.

# %% [markdown]
# #### 30. Filter numbers divisible by both 3 and 5.

# %% [markdown]
# ### LEVEL 4 – LAMBDA WITH `reduce()`

# %% [markdown]
# #### 31. Find sum of list.

# %% [markdown]
# #### 32. Find product of list.

# %% [markdown]
# #### 33. Find maximum element.

# %% [markdown]
# #### 34. Find minimum element.

# %% [markdown]
# #### 35. Find factorial of a number.

# %% [markdown]
# #### 36. Find longest string.

# %% [markdown]
# #### 37. Count even numbers.

# %% [markdown]
# #### 38. Merge list of dictionaries.

# %% [markdown]
# #### 39. Flatten list of lists.

# %% [markdown]
# #### 40. Find GCD of list of numbers.

# %% [markdown]
# #### LEVEL 5 – ADVANCED INTERVIEW QUESTIONS

# %% [markdown]
# #### 41. Sort list of tuples by second element using lambda.

# %% [markdown]
# #### 42. Sort list of dictionaries by key.

# %% [markdown]
# #### 43. Sort strings by last character.

# %% [markdown]
# #### 44. Find second largest number using lambda.

# %% [markdown]
# #### 45. Combine map + filter in one expression.

# %% [markdown]
# #### 46. Remove duplicates while preserving order.

# %% [markdown]
# #### 47. Build frequency dictionary using reduce.

# %% [markdown]
# #### 48. Find first non-repeating character.

# %% [markdown]
# #### 49. Implement custom max() using reduce.

# %% [markdown]
# #### 50. Chain map → filter → reduce in single pipeline.
