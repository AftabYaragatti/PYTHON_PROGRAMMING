# %% [markdown]
# ## MATCH STATEMENTS

# %% [markdown]
# ### LEVEL 1 – BASIC MATCH

# %% [markdown]
# #### 1. Print day name based on number (1–7).

# %% [markdown]
# #### 2. Print month name based on number.

# %% [markdown]
# #### 3. Simple calculator using match (+, -, *, /).

# %% [markdown]
# #### 4. Print traffic signal action (Red/Yellow/Green).

# %% [markdown]
# #### 5. Check vowel or consonant.

# %% [markdown]
# #### 6. Print weekday or weekend.

# %% [markdown]
# #### 7. Check student grade (A, B, C, Fail).

# %% [markdown]
# #### 8. Print menu option (1: Deposit, 2: Withdraw).

# %% [markdown]
# #### 9. Print season based on month.

# %% [markdown]
# #### 10. Check simple login role (Admin/User/Guest).

# %% [markdown]
# ### LEVEL 2 – INTERMEDIATE

# %% [markdown]
# #### 11. ATM menu system using match.

# %% [markdown]
# #### 12. Movie ticket category (Child/Adult/Senior).

# %% [markdown]
# #### 13. Convert number (1–5) to word.

# %% [markdown]
# #### 14. Restaurant order system.

# %% [markdown]
# #### 15. Bank account type (Savings/Current).

# %% [markdown]
# #### 16. E-commerce payment method.

# %% [markdown]
# #### 17. Vehicle type classification.

# %% [markdown]
# #### 18. Shape area calculator.

# %% [markdown]
# #### 19. Weather type display.

# %% [markdown]
# #### 20. Subject selection system.

# %% [markdown]
# ### LEVEL 3 – MULTIPLE CASES & PATTERN MATCHING

# %% [markdown]
# #### 21. Group multiple days under “Weekday”.

# %% [markdown]
# #### 22. Group multiple months under “Winter”.

# %% [markdown]
# #### 23. Match multiple grades under “Pass”.

# %% [markdown]
# #### 24. Use `_` default case.

# %% [markdown]
# #### 25. Match integer vs string input.

# %% [markdown]
# #### 26. Match tuple values.

# %% [markdown]
# #### 27. Match list patterns.

# %% [markdown]
# #### 28. Match dictionary patterns.

# %% [markdown]
# #### 29. Match nested data structures.

# %% [markdown]
# #### 30. Use `if` guard inside match.

# %% [markdown]
# ### LEVEL 4 – ADVANCED STRUCTURAL PATTERN MATCHING

# %% [markdown]
# #### 31. Match coordinates like `(x, y)`.

# %% [markdown]
# #### 32. Match HTTP status codes.

# %% [markdown]
# #### 33. Match API response format.

# %% [markdown]
# #### 34. Match JSON-like dictionary.

# %% [markdown]
# #### 35. Match nested tuple `(name, age)`.

# %% [markdown]
# #### 36. Match employee role with salary range.

# %% [markdown]
# #### 37. Match student record dictionary.

# %% [markdown]
# #### 38. Match file extension.

# %% [markdown]
# #### 39. Match mathematical expression patterns.

# %% [markdown]
# #### 40. Match command-line arguments.
